# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage1=requests.get('https://vesit.ves.ac.in/result-ug#autonomy').text
webpage2=requests.get('https://vesit.ves.ac.in/placements/placed_students').text

# %%
soup1=BeautifulSoup(webpage1, 'lxml')
soup2=BeautifulSoup(webpage2, 'lxml')

# %%
print(soup1.prettify())
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="wSQH3AvG0a00iS9ox2qcdqmDiIxt3IwImJRJethr" name="csrf-token"/>
#   <meta content="NWQX2w6XEEbfBFA4Wk-8vMK02XQVGhLJb0HG8ugXXmE" name="google-site-verification"/>
#   <title>
#    VESIT
#   </title>
#   <link href="https://vesit.ves.ac.in/manifest.json" rel="manifest"/>
#   <link href="https://vesit.ves.ac.in/css/app.css" rel="stylesheet"/>
#   <link href="https://vesit.ves.ac.in/css/slick.css" rel="stylesheet"/>
#   <link href="https://vesit.ves.ac.in/css/slick-theme.css" rel="stylesheet"/>
#   <script src="https://vesit.ves.ac.in/js/app.js">
#   </script>
#   <script src="https://vesit.ves.ac.in/js/jquery.min.js">
#   </script>
#   <script src="https://vesit.ves.ac.in/js/jquery-migrate.min.js">
#   </script>
#   <script src="https://vesit.ves.ac.in/js/slick.min.js">
#   </script>
# ...

# %%
soup2.find_all('img')
# Out:
# [<img alt="" class="dispheadermob" src="https://vesit.ves.ac.in/navlogo.PNG"/>,
#  <img class="img-fluid" src="https://vesit.ves.ac.in/storage/resize-16821547711898197120ariia.jpg" style="
#      background-size: cover; background-repeat: no-repeat;"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 23-24/Barclays Placed Students.png"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/JPMC Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/ISS Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/Dolat Capital Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/Forcepoint Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/IVP Placed Students.jpg"/>,
# ...

# %%
for i in soup2.find_all('img'):
    print(i.text.strip())

# %%
soup2.find_all('img', class_="img-fluid")
# Out:
# [<img class="img-fluid" src="https://vesit.ves.ac.in/storage/resize-16821547711898197120ariia.jpg" style="
#      background-size: cover; background-repeat: no-repeat;"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 23-24/Barclays Placed Students.png"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/JPMC Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/ISS Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/Dolat Capital Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/Forcepoint Placed Students.jpeg"/>,
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/IVP Placed Students.jpg"/>,
# ...

# %%
soup2.find_all('div', class_="col-sm-3 mb-3")
# Out:
# [<div class="col-sm-3 mb-3">
#  <div class="card">
#  <div class="card-header text-center">
#  <b>Barclays</b>
#  </div>
#  <div class="card-body">
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 23-24/Barclays Placed Students.png"/>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-3 mb-3">
#  <div class="card">
#  <div class="card-header text-center">
#  <b>JP Morgan &amp; Chase</b>
#  </div>
#  <div class="card-body">
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/JPMC Placed Students.jpeg"/>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-3 mb-3">
#  <div class="card">
#  <div class="card-header text-center">
#  <b>Institutional Shareholder Services (ISS)</b>
#  </div>
#  <div class="card-body">
#  <img alt="" class="img-fluid" src="https://vesit.ves.ac.in/storage/placements/AY 22-23/ISS Placed Students.jpeg"/>
#  </div>
#  </div>
#  </div>,
#  <div class="col-sm-3 mb-3">
#  <div class="card">
# ...
